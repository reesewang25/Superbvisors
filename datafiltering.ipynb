# %% [markdown]
# <a href="https://colab.research.google.com/github/reesewang25/Superbvisors/blob/main/datafiltering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import io
import glob
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
#  drive	 sample_data  'stage2.12.2017 (1).csv'	 stage2.12.2017.csv

# %%
# !pwd
# Out:
# /content

# %%
df =pd.read_csv("drive/MyDrive/Colab Notebooks/dsgtfiles/stage2.12.2017.csv")

# %%
df
# Out:
#       incident_id        date           state               city_or_county  \
# 0         1000709  2017-12-01  North Carolina                      Cameron
# 1          999981  2017-12-01        Kentucky                     Danville
# 2          999105  2017-12-01            Ohio                       Toledo
# 3         1000715  2017-12-01      Washington                     Longview
# 4          999403  2017-12-01       Minnesota  Minneapolis (Brooklyn Park)
# ...           ...         ...             ...                          ...
# 4617      1021518  2017-12-31      New Mexico                 Mesilla Park
# 4618      1017652  2017-12-31            Ohio                Mechanicsburg
# 4619      1018216  2017-12-31  North Carolina                      Sanford
# 4620      1069150  2017-12-31        Delaware                   Wilmington
# 4621      1019212  2017-12-31        Kentucky                      Robards
#
#                             address  n_killed  n_injured  \
# ...

# %%
df.isnull().sum()
# Out:
# incident_id                       0
# date                              0
# state                             0
# city_or_county                    0
# address                         236
# n_killed                          0
# n_injured                         0
# incident_url                      0
# source_url                       10
# incident_url_fields_missing       0
# congressional_district          631
# gun_stolen                       14
# gun_type                         14
# incident_characteristics          1
# latitude                         94
# location_description           3720
# longitude                        94
# n_guns_involved                  14
# notes                          1455
# participant_age                1754
# participant_age_group           844
# participant_gender              720
# participant_name               2234
# participant_relationship       4300
# participant_status              502
# participant_type                462
# ...

# %%
minidf = df[['date','state','n_killed','n_injured','incident_characteristics']]

# %%
minidf
# Out:
#             date           state  n_killed  n_injured  \
# 0     2017-12-01  North Carolina         0          1
# 1     2017-12-01        Kentucky         0          0
# 2     2017-12-01            Ohio         0          1
# 3     2017-12-01      Washington         0          0
# 4     2017-12-01       Minnesota         0          1
# ...          ...             ...       ...        ...
# 4617  2017-12-31      New Mexico         0          0
# 4618  2017-12-31            Ohio         1          1
# 4619  2017-12-31  North Carolina         0          1
# 4620  2017-12-31        Delaware         0          0
# 4621  2017-12-31        Kentucky         0          1
#
#                                incident_characteristics
# 0     Shot - Wounded/Injured||Home Invasion||Home In...
# 1     Non-Shooting Incident||School Incident||Gun at...
# 2                                Shot - Wounded/Injured
# 3     Non-Shooting Incident||Drug involvement||Gun(s...
# ...

# %% [markdown]
# Tried to import csv files for all years

# %%
os.chdir("drive/My Drive/Colab Notebooks/dsgtfiles")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])

#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('combined_csv.csv')

# %%
df
# Out:
#         incident_id        date           state               city_or_county  \
# 0           1000709  2017-12-01  North Carolina                      Cameron
# 1            999981  2017-12-01        Kentucky                     Danville
# 2            999105  2017-12-01            Ohio                       Toledo
# 3           1000715  2017-12-01      Washington                     Longview
# 4            999403  2017-12-01       Minnesota  Minneapolis (Brooklyn Park)
# ...             ...         ...             ...                          ...
# 238758       949014  2017-09-30        Arkansas                  Little Rock
# 238759       945729  2017-09-30     Mississippi                     Columbus
# 238760       946012  2017-09-30         Florida               Port Charlotte
# 238761       949234  2017-09-30         Alabama                          Opp
# 238762       949439  2017-09-30         Alabama                   Rainsville
#
# ...

# %%
df.isnull().sum()
# Out:
# incident_id                         0
# date                                0
# state                               0
# city_or_county                      0
# address                         16391
# n_killed                            0
# n_injured                           0
# incident_url                        0
# source_url                        464
# incident_url_fields_missing         0
# congressional_district          12532
# gun_stolen                      99313
# gun_type                        99266
# incident_characteristics          323
# latitude                         8005
# location_description           197366
# longitude                        8005
# n_guns_involved                 99266
# notes                           80859
# participant_age                 92170
# participant_age_group           42045
# participant_gender              36301
# participant_name               121907
# participant_relationship       223187
# participant_status              27588
# ...

# %%
minidf = df[['date','state','n_killed','n_injured','incident_characteristics']]
minidf
# Out:
#               date           state  n_killed  n_injured  \
# 0       2017-12-01  North Carolina         0          1
# 1       2017-12-01        Kentucky         0          0
# 2       2017-12-01            Ohio         0          1
# 3       2017-12-01      Washington         0          0
# 4       2017-12-01       Minnesota         0          1
# ...            ...             ...       ...        ...
# 238758  2017-09-30        Arkansas         0          1
# 238759  2017-09-30     Mississippi         0          1
# 238760  2017-09-30         Florida         1          0
# 238761  2017-09-30         Alabama         0          1
# 238762  2017-09-30         Alabama         0          1
#
#                                  incident_characteristics
# 0       Shot - Wounded/Injured||Home Invasion||Home In...
# 1       Non-Shooting Incident||School Incident||Gun at...
# 2                                  Shot - Wounded/Injured
# ...
